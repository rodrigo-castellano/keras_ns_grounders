# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import csv
import re
from collections import defaultdict

# %%
# This will make the nested defaultdict picklable.  
def nested_dict(n, type):
    """
    Creates a nested defaultdict with n levels.

    Parameters:
    n (int): The number of nested levels for the defaultdict.
    type: The default data type for the defaultdict.

    Returns:
    defaultdict: A nested defaultdict with n levels.
    """
    def create_nested_dict(n, type):
        # A helper function that creates a nested defaultdict with n levels
        if n == 1:
            return defaultdict(type)
        else:
            return defaultdict(lambda: create_nested_dict(n-1, type))

    return create_nested_dict(n, type)

def drop_duplicates_except_metric(results,cols,rows):
    # Remove duplicates
    n_rows_before = len(results.index)
    cols_subset = [i for i in results.columns if i != 'test_task_mrr']
    results = results.drop_duplicates(subset=[cols,rows], keep='first')
    n_rows_after = len(results.index)
    print('n_rows_before',n_rows_before, 'n_rows_after', n_rows_after) if n_rows_before != n_rows_after else None
    return results

def string2list(df):
    for column in df:
        try:
            # For all the colum, apply eval() to convert the string to a list
            if column != 'kge':
                df[column] = [np.array(eval(i)) for i in df[column].values]
        except:
            # print("Couldnt convert ", column)
            continue

    # for each col that is a string or int or object, print the unique values 
    print('\nUnique values:')
    for col in df.columns:
        try: 
            if df[col].dtype == 'object' or df[col].dtype == 'int64' or df[col].dtype == 'string':
                print(col,df[col].unique())
        except:
            continue
    return df

def split_df(df):
    # create a df that is the same as the original but with the first value of the colums in the list metrics
    df_mean = df.copy()
    df_std = df.copy()
    for col in df_mean.columns:
        try:
            # df_mean[col] = [i[0] for i in df_mean[col].values]
            vals = []
            for i in df_mean[col].values:
                if i is not np.nan:
                    vals.append(i[0])
                else:
                    vals.append(i)
            # substitute the values of the col with the new values
            df_mean[col] = vals
        except:
            continue
    # Do the same for the std
    for col in df_std.columns:
        try:
            # df_std[col] = [i[1] for i in df_std[col].values]
            vals = []
            for i in df_std[col].values:
                if i is not np.nan:
                    vals.append(i[1])
                else:
                    vals.append(i)
            # substitute the values of the col with the new values
            df_std[col] = vals
        except:
            continue
    return df_mean, df_std

# %%
tasks = [
            "pharmkg_small", "pharmkg_small_reason_2","pharmkg_full",
            "kinship_family","kinship_family_reason_2",
            "nations",'countries_s1', 'countries_s2','countries_s2_3rules', 'countries_s3',
        ]
names_files = [""]# , ,'pharmkg',"long","nations",'kinship']
root = "C:\\Users\\rodri\\Downloads\\PhD\\Review_grounders\\keras_ns_grounders\\experiments\\countries\\results\\batched\\experiments\\"
for i,file in enumerate(names_files):
    path = root + "experiments"  + file + ".csv"
    dfi = pd.read_csv(path, sep=';', keep_default_na=False, skiprows=0)
    dfi = dfi.drop_duplicates()
    if i == 0:
        df = dfi
    else:
        df = pd.concat([df, dfi], ignore_index=True)
df = df.drop_duplicates()
df = string2list(df)
# to avoid problems with the None from Rule miner
df['rule_miner'] = df['rule_miner'].apply(lambda x: 'No' if str(x) == 'None' else x)
print(df)
# Out:
# Unique values:
# model_name ['no_reasoner' 'sbr' 'rnm' 'dcr' 'r2n']
# dataset_name ['countries_s1' 'countries_s2' 'countries_s2_3rules']
# grounder ['backward_1' 'backward_2' 'backward_3']
# kge ['complex']
# kge_atom_embedding_size [100]
# facts_file ['facts.txt']
# train_file ['train.txt']
# valid_file ['valid.txt']
# test_file ['test.txt']
# domain_file ['domain2constants.txt']
# rules_file ['rules.txt']
# num_negatives [1]
# valid_negatives [100]
# format ['functional']
# engine_num_negatives [0]
# engine_num_adaptive_constants [0]
# constant_embedding_size [200]
# epochs [100]
# num_rules [0 1]
# loss ['binary_crossentropy']
# batch_size [128]
# val_batch_size [-1]
# test_batch_size [64]
# cdcr_num_formulas [3]
# valid_frequency [3]
# reasoner_depth [1]
# reasoner_formula_hidden_embedding_size [100]
# reasoner_atom_embedding_size [100]
# filter_num_heads [3]
# run_signature ['countries_s1-backward_1-complex-no_reasoner-None-1-100'
#  'countries_s1-backward_1-complex-sbr-None-1-100'
#  'countries_s1-backward_1-complex-rnm-None-1-100'
#  'countries_s1-backward_1-complex-dcr-None-1-100'
#  'countries_s1-backward_1-complex-r2n-None-1-100'
#  'countries_s1-backward_2-complex-no_reasoner-None-1-100'
#  'countries_s1-backward_2-complex-sbr-None-1-100'
#  'countries_s1-backward_2-complex-rnm-None-1-100'
#  'countries_s1-backward_2-complex-dcr-None-1-100'
#  'countries_s1-backward_2-complex-r2n-None-1-100'
#  'countries_s1-backward_3-complex-no_reasoner-None-1-100'
#  'countries_s1-backward_3-complex-sbr-None-1-100'
#  'countries_s1-backward_3-complex-rnm-None-1-100'
#  'countries_s1-backward_3-complex-dcr-None-1-100'
#  'countries_s1-backward_3-complex-r2n-None-1-100'
#  'countries_s2-backward_1-complex-no_reasoner-None-1-100'
#  'countries_s2-backward_1-complex-sbr-None-1-100'
#  'countries_s2-backward_1-complex-rnm-None-1-100'
#  'countries_s2-backward_1-complex-dcr-None-1-100'
#  'countries_s2-backward_1-complex-r2n-None-1-100'
#  'countries_s2-backward_2-complex-no_reasoner-None-1-100'
#  'countries_s2-backward_2-complex-sbr-None-1-100'
#  'countries_s2-backward_2-complex-rnm-None-1-100'
#  'countries_s2-backward_2-complex-dcr-None-1-100'
#  'countries_s2-backward_2-complex-r2n-None-1-100'
#  'countries_s2-backward_3-complex-no_reasoner-None-1-100'
#  'countries_s2-backward_3-complex-sbr-None-1-100'
#  'countries_s2-backward_3-complex-rnm-None-1-100'
#  'countries_s2-backward_3-complex-dcr-None-1-100'
#  'countries_s2-backward_3-complex-r2n-None-1-100'
#  'countries_s2_3rules-backward_1-complex-no_reasoner-None-1-100'
#  'countries_s2_3rules-backward_1-complex-sbr-None-1-100'
#  'countries_s2_3rules-backward_1-complex-rnm-None-1-100'
#  'countries_s2_3rules-backward_1-complex-dcr-None-1-100'
#  'countries_s2_3rules-backward_1-complex-r2n-None-1-100'
#  'countries_s2_3rules-backward_2-complex-no_reasoner-None-1-100'
#  'countries_s2_3rules-backward_2-complex-sbr-None-1-100'
#  'countries_s2_3rules-backward_2-complex-rnm-None-1-100'
#  'countries_s2_3rules-backward_2-complex-dcr-None-1-100'
#  'countries_s2_3rules-backward_2-complex-r2n-None-1-100'
#  'countries_s2_3rules-backward_3-complex-no_reasoner-None-1-100']
# seed_run_i [4]
#                seed   model_name         dataset_name    grounder      kge  \
# 0   [0, 1, 2, 3, 4]  no_reasoner         countries_s1  backward_1  complex
# 1   [0, 1, 2, 3, 4]  no_reasoner         countries_s1  backward_1  complex
# 2   [0, 1, 2, 3, 4]          sbr         countries_s1  backward_1  complex
# 3   [0, 1, 2, 3, 4]          rnm         countries_s1  backward_1  complex
# 4   [0, 1, 2, 3, 4]          dcr         countries_s1  backward_1  complex
# 5   [0, 1, 2, 3, 4]          r2n         countries_s1  backward_1  complex
# 6   [0, 1, 2, 3, 4]  no_reasoner         countries_s1  backward_2  complex
# 7   [0, 1, 2, 3, 4]          sbr         countries_s1  backward_2  complex
# 8   [0, 1, 2, 3, 4]          rnm         countries_s1  backward_2  complex
# 9   [0, 1, 2, 3, 4]          dcr         countries_s1  backward_2  complex
# 10  [0, 1, 2, 3, 4]          r2n         countries_s1  backward_2  complex
# 11  [0, 1, 2, 3, 4]  no_reasoner         countries_s1  backward_3  complex
# 12  [0, 1, 2, 3, 4]          sbr         countries_s1  backward_3  complex
# 13  [0, 1, 2, 3, 4]          rnm         countries_s1  backward_3  complex
# 14  [0, 1, 2, 3, 4]          dcr         countries_s1  backward_3  complex
# 15  [0, 1, 2, 3, 4]          r2n         countries_s1  backward_3  complex
# 16  [0, 1, 2, 3, 4]  no_reasoner         countries_s2  backward_1  complex
# 17  [0, 1, 2, 3, 4]          sbr         countries_s2  backward_1  complex
# 18  [0, 1, 2, 3, 4]          rnm         countries_s2  backward_1  complex
# 19  [0, 1, 2, 3, 4]          dcr         countries_s2  backward_1  complex
# 20  [0, 1, 2, 3, 4]          r2n         countries_s2  backward_1  complex
# 21  [0, 1, 2, 3, 4]  no_reasoner         countries_s2  backward_2  complex
# 22  [0, 1, 2, 3, 4]          sbr         countries_s2  backward_2  complex
# 23  [0, 1, 2, 3, 4]          rnm         countries_s2  backward_2  complex
# 24  [0, 1, 2, 3, 4]          dcr         countries_s2  backward_2  complex
# 25  [0, 1, 2, 3, 4]          r2n         countries_s2  backward_2  complex
# 26  [0, 1, 2, 3, 4]  no_reasoner         countries_s2  backward_3  complex
# 27  [0, 1, 2, 3, 4]          sbr         countries_s2  backward_3  complex
# 28  [0, 1, 2, 3, 4]          rnm         countries_s2  backward_3  complex
# 29  [0, 1, 2, 3, 4]          dcr         countries_s2  backward_3  complex
# 30  [0, 1, 2, 3, 4]          r2n         countries_s2  backward_3  complex
# 31  [0, 1, 2, 3, 4]  no_reasoner  countries_s2_3rules  backward_1  complex
# 32  [0, 1, 2, 3, 4]          sbr  countries_s2_3rules  backward_1  complex
# 33  [0, 1, 2, 3, 4]          rnm  countries_s2_3rules  backward_1  complex
# 34  [0, 1, 2, 3, 4]          dcr  countries_s2_3rules  backward_1  complex
# 35  [0, 1, 2, 3, 4]          r2n  countries_s2_3rules  backward_1  complex
# 36  [0, 1, 2, 3, 4]  no_reasoner  countries_s2_3rules  backward_2  complex
# 37  [0, 1, 2, 3, 4]          sbr  countries_s2_3rules  backward_2  complex
# 38  [0, 1, 2, 3, 4]          rnm  countries_s2_3rules  backward_2  complex
# 39  [0, 1, 2, 3, 4]          dcr  countries_s2_3rules  backward_2  complex
# 40  [0, 1, 2, 3, 4]          r2n  countries_s2_3rules  backward_2  complex
# 41  [0, 1, 2, 3, 4]  no_reasoner  countries_s2_3rules  backward_3  complex
#
#    rule_miner  kge_atom_embedding_size facts_file train_file valid_file  ...  \
# 0          No                      100  facts.txt  train.txt  valid.txt  ...
# 1          No                      100  facts.txt  train.txt  valid.txt  ...
# 2          No                      100  facts.txt  train.txt  valid.txt  ...
# 3          No                      100  facts.txt  train.txt  valid.txt  ...
# 4          No                      100  facts.txt  train.txt  valid.txt  ...
# 5          No                      100  facts.txt  train.txt  valid.txt  ...
# 6          No                      100  facts.txt  train.txt  valid.txt  ...
# 7          No                      100  facts.txt  train.txt  valid.txt  ...
# 8          No                      100  facts.txt  train.txt  valid.txt  ...
# 9          No                      100  facts.txt  train.txt  valid.txt  ...
# 10         No                      100  facts.txt  train.txt  valid.txt  ...
# 11         No                      100  facts.txt  train.txt  valid.txt  ...
# 12         No                      100  facts.txt  train.txt  valid.txt  ...
# 13         No                      100  facts.txt  train.txt  valid.txt  ...
# 14         No                      100  facts.txt  train.txt  valid.txt  ...
# 15         No                      100  facts.txt  train.txt  valid.txt  ...
# 16         No                      100  facts.txt  train.txt  valid.txt  ...
# 17         No                      100  facts.txt  train.txt  valid.txt  ...
# 18         No                      100  facts.txt  train.txt  valid.txt  ...
# 19         No                      100  facts.txt  train.txt  valid.txt  ...
# 20         No                      100  facts.txt  train.txt  valid.txt  ...
# 21         No                      100  facts.txt  train.txt  valid.txt  ...
# 22         No                      100  facts.txt  train.txt  valid.txt  ...
# 23         No                      100  facts.txt  train.txt  valid.txt  ...
# 24         No                      100  facts.txt  train.txt  valid.txt  ...
# 25         No                      100  facts.txt  train.txt  valid.txt  ...
# 26         No                      100  facts.txt  train.txt  valid.txt  ...
# 27         No                      100  facts.txt  train.txt  valid.txt  ...
# 28         No                      100  facts.txt  train.txt  valid.txt  ...
# 29         No                      100  facts.txt  train.txt  valid.txt  ...
# 30         No                      100  facts.txt  train.txt  valid.txt  ...
# 31         No                      100  facts.txt  train.txt  valid.txt  ...
# 32         No                      100  facts.txt  train.txt  valid.txt  ...
# 33         No                      100  facts.txt  train.txt  valid.txt  ...
# 34         No                      100  facts.txt  train.txt  valid.txt  ...
# 35         No                      100  facts.txt  train.txt  valid.txt  ...
# 36         No                      100  facts.txt  train.txt  valid.txt  ...
# 37         No                      100  facts.txt  train.txt  valid.txt  ...
# 38         No                      100  facts.txt  train.txt  valid.txt  ...
# 39         No                      100  facts.txt  train.txt  valid.txt  ...
# 40         No                      100  facts.txt  train.txt  valid.txt  ...
# 41         No                      100  facts.txt  train.txt  valid.txt  ...
#
#          test_loss test_concept_loss  test_task_loss  test_concept_mrr  \
# 0   [0.252, 0.049]    [0.252, 0.049]  [0.252, 0.049]    [0.971, 0.013]
# 1   [0.299, 0.159]    [0.299, 0.159]  [0.299, 0.159]    [0.966, 0.024]
# 2   [0.164, 0.068]    [0.309, 0.132]  [0.019, 0.008]    [0.981, 0.013]
# 3   [0.302, 0.104]    [0.425, 0.143]  [0.179, 0.065]    [0.959, 0.013]
# 4   [0.254, 0.025]    [0.499, 0.051]  [0.004, 0.001]    [0.975, 0.005]
# 5   [0.216, 0.124]    [0.228, 0.122]  [0.204, 0.131]    [0.976, 0.027]
# 6   [0.345, 0.209]    [0.345, 0.209]  [0.345, 0.209]     [0.961, 0.03]
# 7   [0.345, 0.209]    [0.345, 0.209]  [0.345, 0.209]     [0.961, 0.03]
# 8   [0.345, 0.209]    [0.345, 0.209]  [0.345, 0.209]     [0.961, 0.03]
# 9   [0.352, 0.209]    [0.352, 0.209]  [0.352, 0.209]    [0.972, 0.022]
# 10  [0.362, 0.189]    [0.362, 0.189]  [0.362, 0.189]    [0.972, 0.017]
# 11  [0.345, 0.209]    [0.345, 0.209]  [0.345, 0.209]     [0.961, 0.03]
# 12  [0.345, 0.209]    [0.345, 0.209]  [0.345, 0.209]     [0.961, 0.03]
# 13  [0.345, 0.209]    [0.345, 0.209]  [0.345, 0.209]     [0.961, 0.03]
# 14  [0.352, 0.209]    [0.352, 0.209]  [0.352, 0.209]    [0.972, 0.022]
# 15  [0.362, 0.189]    [0.362, 0.189]  [0.362, 0.189]    [0.972, 0.017]
# 16  [0.301, 0.058]    [0.301, 0.058]  [0.301, 0.058]    [0.936, 0.009]
# 17  [0.242, 0.065]    [0.242, 0.066]  [0.241, 0.065]    [0.944, 0.011]
# 18  [0.266, 0.031]    [0.266, 0.031]  [0.266, 0.031]    [0.945, 0.012]
# 19    [0.31, 0.12]    [0.306, 0.123]  [0.305, 0.123]    [0.944, 0.014]
# 20  [0.246, 0.104]    [0.255, 0.101]  [0.238, 0.109]    [0.948, 0.036]
# 21  [0.301, 0.058]    [0.301, 0.058]  [0.301, 0.058]    [0.936, 0.009]
# 22  [0.301, 0.058]    [0.301, 0.058]  [0.301, 0.058]    [0.936, 0.009]
# 23  [0.301, 0.058]    [0.301, 0.058]  [0.301, 0.058]    [0.936, 0.009]
# 24  [0.341, 0.125]    [0.341, 0.125]  [0.341, 0.125]    [0.949, 0.028]
# 25  [0.359, 0.085]    [0.359, 0.085]  [0.359, 0.085]    [0.922, 0.015]
# 26  [0.301, 0.058]    [0.301, 0.058]  [0.301, 0.058]    [0.936, 0.009]
# 27  [0.301, 0.058]    [0.301, 0.058]  [0.301, 0.058]    [0.936, 0.009]
# 28  [0.301, 0.058]    [0.301, 0.058]  [0.301, 0.058]    [0.936, 0.009]
# 29  [0.341, 0.125]    [0.341, 0.125]  [0.341, 0.125]    [0.949, 0.028]
# 30  [0.359, 0.085]    [0.359, 0.085]  [0.359, 0.085]    [0.922, 0.015]
# 31  [0.301, 0.058]    [0.301, 0.058]  [0.301, 0.058]    [0.936, 0.009]
# 32  [0.218, 0.015]    [0.386, 0.024]   [0.05, 0.012]     [0.935, 0.01]
# 33  [0.267, 0.098]    [0.379, 0.135]  [0.155, 0.063]    [0.953, 0.025]
# 34  [0.217, 0.028]    [0.373, 0.058]  [0.048, 0.014]     [0.948, 0.01]
# 35  [0.351, 0.197]    [0.352, 0.197]  [0.349, 0.198]    [0.946, 0.035]
# 36  [0.301, 0.058]    [0.301, 0.058]  [0.301, 0.058]    [0.936, 0.009]
# 37  [0.265, 0.031]    [0.265, 0.031]  [0.265, 0.031]    [0.947, 0.013]
# 38  [0.265, 0.031]    [0.265, 0.031]  [0.265, 0.031]    [0.947, 0.013]
# 39  [0.369, 0.069]     [0.368, 0.07]   [0.368, 0.07]    [0.933, 0.017]
# 40  [0.363, 0.167]    [0.364, 0.166]  [0.362, 0.167]    [0.941, 0.024]
# 41  [0.301, 0.058]    [0.301, 0.058]  [0.301, 0.058]    [0.936, 0.009]
#
#     test_concept_hits@1@1 test_concept_hits@3@3   test_task_mrr  \
# 0           [0.948, 0.02]            [1.0, 0.0]  [0.971, 0.013]
# 1          [0.942, 0.036]        [0.994, 0.013]  [0.966, 0.024]
# 2          [0.963, 0.025]            [1.0, 0.0]      [1.0, 0.0]
# 3          [0.924, 0.027]         [0.992, 0.01]  [0.998, 0.004]
# 4          [0.956, 0.008]         [0.992, 0.01]      [1.0, 0.0]
# 5           [0.96, 0.051]         [0.992, 0.01]  [0.976, 0.027]
# 6          [0.936, 0.046]        [0.988, 0.016]   [0.961, 0.03]
# 7          [0.936, 0.046]        [0.988, 0.016]   [0.961, 0.03]
# 8          [0.936, 0.046]        [0.988, 0.016]   [0.961, 0.03]
# 9          [0.952, 0.037]         [0.992, 0.01]  [0.972, 0.022]
# 10         [0.952, 0.027]         [0.992, 0.01]  [0.972, 0.017]
# 11         [0.936, 0.046]        [0.988, 0.016]   [0.961, 0.03]
# 12         [0.936, 0.046]        [0.988, 0.016]   [0.961, 0.03]
# 13         [0.936, 0.046]        [0.988, 0.016]   [0.961, 0.03]
# 14         [0.952, 0.037]         [0.992, 0.01]  [0.972, 0.022]
# 15         [0.952, 0.027]         [0.992, 0.01]  [0.972, 0.017]
# 16          [0.892, 0.01]        [0.984, 0.015]  [0.936, 0.009]
# 17         [0.904, 0.015]        [0.992, 0.016]  [0.944, 0.011]
# 18          [0.904, 0.02]        [0.984, 0.015]  [0.945, 0.012]
# 19          [0.912, 0.02]        [0.964, 0.015]  [0.944, 0.014]
# 20         [0.916, 0.056]        [0.972, 0.024]  [0.948, 0.036]
# 21          [0.892, 0.01]        [0.984, 0.015]  [0.936, 0.009]
# 22          [0.892, 0.01]        [0.984, 0.015]  [0.936, 0.009]
# 23          [0.892, 0.01]        [0.984, 0.015]  [0.936, 0.009]
# 24          [0.92, 0.044]        [0.972, 0.016]  [0.949, 0.028]
# 25         [0.876, 0.023]         [0.96, 0.022]  [0.922, 0.015]
# 26          [0.892, 0.01]        [0.984, 0.015]  [0.936, 0.009]
# 27          [0.892, 0.01]        [0.984, 0.015]  [0.936, 0.009]
# 28          [0.892, 0.01]        [0.984, 0.015]  [0.936, 0.009]
# 29          [0.92, 0.044]        [0.972, 0.016]  [0.949, 0.028]
# 30         [0.876, 0.023]         [0.96, 0.022]  [0.922, 0.015]
# 31          [0.892, 0.01]        [0.984, 0.015]  [0.936, 0.009]
# 32           [0.9, 0.018]         [0.956, 0.02]  [0.994, 0.005]
# 33         [0.924, 0.046]         [0.976, 0.02]  [0.992, 0.004]
# 34         [0.916, 0.015]         [0.976, 0.02]  [0.996, 0.005]
# 35         [0.916, 0.046]         [0.972, 0.03]  [0.946, 0.035]
# 36          [0.892, 0.01]        [0.984, 0.015]  [0.936, 0.009]
# 37          [0.908, 0.02]        [0.984, 0.015]  [0.947, 0.013]
# 38          [0.908, 0.02]        [0.984, 0.015]  [0.947, 0.013]
# 39         [0.896, 0.027]        [0.968, 0.024]  [0.933, 0.017]
# 40         [0.904, 0.032]        [0.972, 0.039]  [0.941, 0.024]
# 41          [0.892, 0.01]        [0.984, 0.015]  [0.936, 0.009]
#
#    test_task_hits@1@1  test_task_hits@3@3                time
# 0       [0.948, 0.02]          [1.0, 0.0]       [21.47, 0.57]
# 1      [0.942, 0.036]      [0.994, 0.013]     [21.383, 0.648]
# 2          [1.0, 0.0]          [1.0, 0.0]     [25.305, 0.263]
# 3      [0.996, 0.008]          [1.0, 0.0]       [25.42, 0.31]
# 4          [1.0, 0.0]          [1.0, 0.0]      [30.62, 0.452]
# 5       [0.96, 0.051]       [0.992, 0.01]     [26.061, 0.115]
# 6      [0.936, 0.046]      [0.988, 0.016]     [21.248, 0.522]
# 7      [0.936, 0.046]      [0.988, 0.016]     [26.353, 0.044]
# 8      [0.936, 0.046]      [0.988, 0.016]     [26.873, 0.076]
# 9      [0.952, 0.037]       [0.992, 0.01]     [31.544, 0.137]
# 10     [0.952, 0.027]       [0.992, 0.01]     [27.498, 0.804]
# 11     [0.936, 0.046]      [0.988, 0.016]     [21.149, 1.156]
# 12     [0.936, 0.046]      [0.988, 0.016]     [27.062, 0.953]
# 13     [0.936, 0.046]      [0.988, 0.016]     [26.283, 1.303]
# 14     [0.952, 0.037]       [0.992, 0.01]     [32.003, 1.168]
# 15     [0.952, 0.027]       [0.992, 0.01]      [27.572, 1.54]
# 16      [0.892, 0.01]      [0.984, 0.015]     [21.418, 1.635]
# 17     [0.904, 0.015]      [0.992, 0.016]    [371.331, 4.152]
# 18      [0.904, 0.02]      [0.984, 0.015]    [372.356, 3.646]
# 19      [0.912, 0.02]      [0.964, 0.015]    [382.722, 4.095]
# 20     [0.916, 0.056]      [0.972, 0.024]    [373.806, 2.756]
# 21      [0.892, 0.01]      [0.984, 0.015]     [21.867, 2.246]
# 22      [0.892, 0.01]      [0.984, 0.015]    [688.704, 2.289]
# 23      [0.892, 0.01]      [0.984, 0.015]    [688.206, 1.964]
# 24      [0.92, 0.044]      [0.972, 0.016]    [700.865, 2.447]
# 25     [0.876, 0.023]       [0.96, 0.022]    [695.039, 3.277]
# 26      [0.892, 0.01]      [0.984, 0.015]     [21.123, 2.096]
# 27      [0.892, 0.01]      [0.984, 0.015]    [727.505, 2.214]
# 28      [0.892, 0.01]      [0.984, 0.015]    [730.288, 2.809]
# 29      [0.92, 0.044]      [0.972, 0.016]    [742.866, 1.389]
# 30     [0.876, 0.023]       [0.96, 0.022]    [735.556, 3.595]
# 31      [0.892, 0.01]      [0.984, 0.015]     [21.429, 2.612]
# 32      [0.988, 0.01]          [1.0, 0.0]   [2023.005, 13.82]
# 33        [0.98, 0.0]          [1.0, 0.0]  [2011.428, 13.246]
# 34      [0.992, 0.01]          [1.0, 0.0]  [2053.416, 10.939]
# 35     [0.916, 0.046]       [0.972, 0.03]    [2044.791, 5.72]
# 36      [0.892, 0.01]      [0.984, 0.015]     [21.766, 3.205]
# 37      [0.908, 0.02]      [0.984, 0.015]  [8739.104, 27.769]
# 38      [0.908, 0.02]      [0.984, 0.015]  [8767.232, 12.941]
# 39     [0.896, 0.027]      [0.968, 0.024]  [8802.868, 15.336]
# 40     [0.904, 0.032]      [0.972, 0.039]  [8799.942, 45.998]
# 41      [0.892, 0.01]      [0.984, 0.015]      [21.911, 3.54]
#
# [42 rows x 76 columns]

# %%
# # Function to replace every cell in the 'Task' column containing 'reason' with the string until 'reason'
# def replace_until_reason(cell_value):
#     match = re.search(r'reason', cell_value)
#     if match:
#         return cell_value[:match.end()]
#     else:
#         return cell_value

# # Apply the function to each cell in the 'Task' column
# df['Task'] = df['Task'].apply(replace_until_reason)
# print(df['Task'].unique())

# %%
cols = 'grounder'
rows = 'model_name'
step = 'test'
metrics = [step+'_task_mrr']#, 'time']
KGEs = ['complex'] #, 'distmult', 'transe']
baseline_model = 'no_reasoner'
baseline_metric = step + '_concept_mrr'
# select the rows from df where the column models has the values ['dcr','mno_reasoner'] 
models = ['sbr','rnm','dcr','r2n','no_reasoner'] # ,'gsbr','cdcr'
models_name = {'sbr':'SBR', 'rnm':'RNM', 'dcr':'DCR', 'r2n':'R2N', 'no_reasoner':'Baseline'} #, 'gsbr':'GSBR', 'cdcr':'CDCR'
models_name = {'r2n': 'Relational Reasoning Networks [3]' ,'sbr':'Semantic Based Regularization [2]', 'rnm':'Relational Neural Machines', 'dcr':'Deep Concept Reasoner [4]', 'r2n':'Relational Reasoning Networks[3]', 'no_reasoner':'Baseline'} #, 'gsbr':'GSBR', 'cdcr':'CDCR'
models_no_baseline = [i for i in models if i != baseline_model]
df = df.loc[df['model_name'].isin(models)]
rule_miners = ['No', 'amie'] #, 'ncrl']
grounders = ['backward_1', 'backward_2', 'backward_3','domainbody'] #, 'domainbody' ,'full']
ground_name = {'backward_1':'Known Body', 'backward_2':'Backward 2', 'backward_3':'Backward 3', 'full':'Full', 'domainbody':'DomainBody', 
                'backward_prune_1':'Back. prune 1', 'backward_prune_2':'Back. prune 2', 'backward_prune_3':'Back. prune 3'}
metric_names = {step+'_task_mrr':'MRR', 'time':'Time (s)'}
dataset_names = {'countries_s2': 'Countries S2', 'countries_s3': 'Countries S3', 'countries_s1': 'Countries S1', 'nations': 'Nations', 
                 'kinship_family_small': 'Kinship Family Small', 'kinship_family': 'Kinship', 'pharmkg_supersmall': 'PharmKG Supersmall',
                  'kinship_family_reason_2': 'Kinship Family reason (2)',
                  'pharmkg_small': 'PharmKG small', 'pharmkg_full': 'PharmKG','pharmkg_small_reason_2': 'PharmKG small Reason',
                  'countries_s2_3rules': 'Countries S2 3 rules'}

# %% [markdown]
# # Models in x axis

# %% [markdown]
# One table for the different models with KGE complex (also for the other KGEs)
# Another table for the different KGEs
# Another table for the time with the best model and the best KGE

# %%
# Table 1: rows:grounder, cols:Model, values: mrr
csv_dir = "C:\\Users\\rodri\\Downloads\\PhD\\Review_grounders\\keras_ns_grounders\\experiments\\countries\\hparamsearch\\results.csv"
# create the dict dfs with 4 levels of keys: task, KGE, metric, rule_miner
dfs = nested_dict(4, dict)
for task in tasks:
    for metric in metrics:
        for KGE in KGEs:
            for rule_miner in rule_miners:
                print('KGE: ', KGE, ' Metric: ', metric, ' Task: ', task, ' Rule miner: ', rule_miner)
                # verify that the rule miner is within the values of Rule_Miner, else continue
                
                miners_available = df.loc[ (df['Task'] == task) &(df['KGE'] == KGE)]['Rule_Miner'].unique()
                if (rule_miner not in miners_available):
                    print('Not available: rule_miner',rule_miner,'. Available: ',miners_available)
                    continue
                # filter the df
                results = df.loc[ (df['Task'] == task) &(df['KGE'] == KGE) &(df['Rule_Miner'] == rule_miner) ].copy() #& (df['WeightLoss_Task'] == 0.5) & (df['Reasoner_depth'] == 1) & (df['EmbedSize'] == 100)].copy()
                # take only the columns grounder, model, test_task_mrr, test_concept_mrr
                results = results[[cols, rows, metric]]
                # Remove duplicates
                results = drop_duplicates_except_metric(results,cols,rows)
                # put the model_name as colums
                results = results.pivot(index=rows, columns=cols, values=metric)

                if metric == 'test_task_mrr':
                    # in the column no_reasoner, put the values of the column test_concept_mrr
                    substitute = df.loc[(df['Task'] == task) & (df['KGE'] == KGE) &(df['Rule_Miner'] == rule_miner) & (df['Model_name'] == baseline_model)][[cols,rows,baseline_metric]] #& (df['WeightLoss_Task'] == 0.5) & (df['Reasoner_depth'] == 1) & (df['EmbedSize'] == 100)][[cols,rows,baseline_metric]]
                    # drop the duplicates , based on all the colums except for 'test_task_mrr'
                    substitute = drop_duplicates_except_metric(substitute,cols,rows)
                    substitute = substitute.pivot(index=rows, columns=cols, values=baseline_metric)
                    # substitute the values in the table
                    # print('\n\nsubstitute',substitute)
                    # print('\n\nresults',results)
                    if len(substitute) > 0:
                        results.loc[baseline_model] = substitute.loc[baseline_model] 
                    # print('\n\nresults',results)
                
                # obtain one df for the mean and one for the std
                results_mean, results_std = split_df(results)
                # append the results to dfs
                dfs[task][KGE][metric][rule_miner]['mean'] = results_mean
                dfs[task][KGE][metric][rule_miner]['std'] = results_std
                print('\n\nresults_mean',results_mean)
                
                # with open(csv_dir, 'a') as f:
                #     f.write('\n Task : ,' + task + 'KGE : ,' + KGE + ', Metric: ,' + metric)
                #     f.write('\n ') 
                # results.to_csv(csv_dir, mode='a', header=True)  
print(task, KGE, metric, rule_miner)
results_mean
# Out:
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_supersmall  Rule miner:  None
# Not available: rule_miner None . Available:  ['amie']
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_supersmall  Rule miner:  amie
#
#
# results_mean Grounder     backward_1  backward_2  backward_3  domainbody    full   known
# Model_name
# cdcr             0.6569      0.6233      0.6219      0.6745     NaN  0.6663
# dcr              0.6748      0.6606      0.6691      0.6702  0.6721  0.6470
# gsbr             0.6516      0.6533      0.6557      0.6562  0.6535  0.6452
# no_reasoner      0.6516      0.6485      0.6538      0.6538  0.6514  0.6467
# r2n              0.6538      0.6424      0.6464      0.6575  0.6328  0.6522
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_supersmall  Rule miner:  ncrl
# Not available: rule_miner ncrl . Available:  ['amie']
# KGE:  complex  Metric:  Time  Task:  pharmkg_supersmall  Rule miner:  None
# Not available: rule_miner None . Available:  ['amie']
# KGE:  complex  Metric:  Time  Task:  pharmkg_supersmall  Rule miner:  amie
#
#
# results_mean Grounder     backward_1  backward_2  backward_3  domainbody        full  \
# Model_name
# cdcr         507.277899  552.729591  521.179654  564.717846         NaN
# dcr          346.244169  389.327704  411.333678  410.997249  679.716370
# gsbr         141.849140  152.316134  171.988689  163.667935  245.321728
# no_reasoner   32.718155   33.873190   35.603093   35.146879   35.247287
# r2n          185.520413  233.009221  264.658491  199.629222  564.486377
#
# Grounder          known
# Model_name
# cdcr         499.928024
# dcr          420.894858
# gsbr         150.910268
# no_reasoner   33.893680
# r2n          184.402407
# KGE:  complex  Metric:  Time  Task:  pharmkg_supersmall  Rule miner:  ncrl
# Not available: rule_miner ncrl . Available:  ['amie']
# KGE:  complex  Metric:  test_task_mrr  Task:  nations  Rule miner:  None
# Not available: rule_miner None . Available:  ['amie']
# KGE:  complex  Metric:  test_task_mrr  Task:  nations  Rule miner:  amie
# n_rows_before 33 n_rows_after 29
# n_rows_before 7 n_rows_after 6
#
#
# results_mean Grounder     backward_1  backward_2  backward_3  domainbody    full   known
# Model_name
# cdcr             0.6999      0.6900      0.6799      0.6850     NaN  0.6843
# dcr              0.6922      0.6899      0.6910      0.6802  0.6868  0.6846
# gsbr             0.6901      0.6863      0.6853      0.6844  0.6874  0.6848
# no_reasoner      0.6837      0.6822      0.6822      0.6822  0.6816  0.6837
# r2n              0.6946      0.6845      0.6835      0.6814  0.6840  0.6843
# KGE:  complex  Metric:  test_task_mrr  Task:  nations  Rule miner:  ncrl
# Not available: rule_miner ncrl . Available:  ['amie']
# KGE:  complex  Metric:  Time  Task:  nations  Rule miner:  None
# Not available: rule_miner None . Available:  ['amie']
# KGE:  complex  Metric:  Time  Task:  nations  Rule miner:  amie
# n_rows_before 33 n_rows_after 29
#
#
# results_mean Grounder      backward_1  backward_2  backward_3  domainbody        full  \
# Model_name
# cdcr         3566.192959  573.848114  597.838025  598.052139         NaN
# dcr           447.168552  427.587604  443.165902  448.241360  434.801330
# gsbr          192.185536  189.366737  188.045894  184.224854  187.189994
# no_reasoner    84.835395   78.759614   85.226912   80.670363   80.634592
# r2n           224.914607  233.324921  245.697677  222.376803  245.955348
#
# Grounder          known
# Model_name
# cdcr         591.719669
# dcr          416.967377
# gsbr         181.160396
# no_reasoner   79.337051
# r2n          210.663770
# KGE:  complex  Metric:  Time  Task:  nations  Rule miner:  ncrl
# Not available: rule_miner ncrl . Available:  ['amie']
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s1  Rule miner:  None
#
#
# results_mean Grounder     backward_1  backward_2  backward_3  domainbody    full   known
# Model_name
# cdcr             0.9447      0.9331      0.9331      0.9479  0.9467  0.9461
# dcr              0.9413      0.9182      0.9182      0.9129  0.9133  0.9357
# gsbr             0.9117      0.9093      0.9093      0.9152  0.9139  0.9090
# no_reasoner      0.9092      0.9092      0.9092      0.9092  0.9092  0.9092
# r2n              0.9856      0.9069      0.9069      0.9133  0.9130  0.9859
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s1  Rule miner:  amie
# Not available: rule_miner amie . Available:  ['None']
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s1  Rule miner:  ncrl
# Not available: rule_miner ncrl . Available:  ['None']
# KGE:  complex  Metric:  Time  Task:  countries_s1  Rule miner:  None
#
#
# results_mean Grounder     backward_1  backward_2  backward_3  domainbody       full  \
# Model_name
# cdcr          25.230851   27.979351   28.488211   35.259973  48.361850
# dcr           23.660580   24.980670   25.225001   29.174177  34.901103
# gsbr          22.166347   21.901363   22.344719   23.593642  28.296794
# no_reasoner   20.374684   20.486419   19.823590   19.121865  19.845817
# r2n           22.949654   24.879410   23.942093   29.068027  37.650860
#
# Grounder         known
# Model_name
# cdcr         25.633978
# dcr          24.243288
# gsbr         21.449396
# no_reasoner  20.741122
# r2n          22.591142
# KGE:  complex  Metric:  Time  Task:  countries_s1  Rule miner:  amie
# Not available: rule_miner amie . Available:  ['None']
# KGE:  complex  Metric:  Time  Task:  countries_s1  Rule miner:  ncrl
# Not available: rule_miner ncrl . Available:  ['None']
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s2  Rule miner:  None
#
#
# results_mean Grounder     backward_1  backward_2  backward_3   known
# Model_name
# cdcr             0.9202      0.9298      0.9276  0.9214
# dcr              0.9285      0.9263      0.9275  0.9191
# gsbr             0.9229      0.9316      0.9288  0.9121
# no_reasoner      0.9165      0.9165      0.9165  0.9165
# r2n              0.9264      0.9153      0.9288  0.9201
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s2  Rule miner:  amie
# Not available: rule_miner amie . Available:  ['None']
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s2  Rule miner:  ncrl
# Not available: rule_miner ncrl . Available:  ['None']
# KGE:  complex  Metric:  Time  Task:  countries_s2  Rule miner:  None
#
#
# results_mean Grounder     backward_1  backward_2  backward_3      known
# Model_name
# cdcr          38.829591   57.560094   59.155762  28.234164
# dcr           32.263712   50.566610   54.126238  25.736600
# gsbr          28.898369   46.530844   45.184822  23.853446
# no_reasoner   20.471790   19.851794   20.287634  20.549142
# r2n           30.538981   50.398360   57.586779  22.813705
# KGE:  complex  Metric:  Time  Task:  countries_s2  Rule miner:  amie
# Not available: rule_miner amie . Available:  ['None']
# KGE:  complex  Metric:  Time  Task:  countries_s2  Rule miner:  ncrl
# Not available: rule_miner ncrl . Available:  ['None']
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s3  Rule miner:  None
#
#
# results_mean Grounder     backward_1  backward_2  backward_3   known
# Model_name
# cdcr             0.8874      0.8582      0.8656  0.8501
# dcr              0.8715      0.8368      0.8591  0.8446
# gsbr             0.8447      0.8348      0.8531  0.8385
# no_reasoner      0.8465      0.8465      0.8465  0.8465
# r2n              0.8907      0.8888      0.9083  0.8454
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s3  Rule miner:  amie
# Not available: rule_miner amie . Available:  ['None']
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s3  Rule miner:  ncrl
# Not available: rule_miner ncrl . Available:  ['None']
# KGE:  complex  Metric:  Time  Task:  countries_s3  Rule miner:  None
#
#
# results_mean Grounder     backward_1  backward_2  backward_3      known
# Model_name
# cdcr          51.917512  145.466734  276.418879  37.312723
# dcr           47.029749  130.528614  214.071812  33.069488
# gsbr          41.891804  109.391130  183.840453  25.112712
# no_reasoner   20.125511   25.179076   20.065374  19.580590
# r2n           42.415282  126.071614  230.843641  31.847271
# KGE:  complex  Metric:  Time  Task:  countries_s3  Rule miner:  amie
# Not available: rule_miner amie . Available:  ['None']
# KGE:  complex  Metric:  Time  Task:  countries_s3  Rule miner:  ncrl
# Not available: rule_miner ncrl . Available:  ['None']
# countries_s3 complex Time ncrl
# Grounder     backward_1  backward_2  backward_3      known
# Model_name
# cdcr          51.917512  145.466734  276.418879  37.312723
# dcr           47.029749  130.528614  214.071812  33.069488
# gsbr          41.891804  109.391130  183.840453  25.112712
# no_reasoner   20.125511   25.179076   20.065374  19.580590
# r2n           42.415282  126.071614  230.843641  31.847271

# %%
# # for every df of dfs, create a new df with the average over the models
# dfs_avg = nested_dict(4, dict)
# for task in tasks:
#     for metric in metrics:
#         for KGE in KGEs:
#             for rule_miner in rule_miners:
#                 for types in ['mean', 'std']:
#                     print(types, 'KGE: ', KGE, ' Metric: ', metric, ' Task: ', task, ' Rule miner: ', rule_miner)
#                     if rule_miner not in dfs[task][KGE][metric].keys():
#                         continue
#                     dfi = dfs[task][KGE][metric][rule_miner][types].copy()
#                     # select from dfi the models that are in models_no_baseline
#                     dfi = dfi.loc[models_no_baseline]
#                     dfi = dfi.mean(axis=0)
#                     dfi = pd.DataFrame(dfi)
#                     # set the name of the column as the metric
#                     dfi.columns = [metric]
#                     dfs_avg[task][KGE][metric][rule_miner][types] = dfi
#                     # print(dfi)
# dfi

# %% [markdown]
# ## PLOTS

# %%
# Table 1: rows:grounder, cols:Model, values: mrr
metric_names = {step+'_task_mrr':'MRR', 'Time':'Time (s)'}
root_dir = "C:\\Users\\rodri\\Downloads\\PhD\\Review_grounders\\keras_ns_grounders\\experiments\\countries\\hparamsearch\\figures\\"
os.makedirs(root_dir) if not os.path.exists(root_dir) else None
for task in tasks:
    for metric in ['test_task_mrr']:
        for KGE in KGEs:
            for rule_miner in rule_miners:
                print('KGE: ', KGE, ' Metric: ', metric, ' Task: ', task, ' Rule miner: ', rule_miner)
                if rule_miner not in dfs[task][KGE][metric].keys():
                    continue
                df_mean = dfs[task][KGE][metric][rule_miner]['mean']
                df_std = dfs[task][KGE][metric][rule_miner]['std']
                print(df_mean)
                # Remove no reasoner and include a line where it is written baseline
                plt.figure(figsize=(10,5))
                for i,grounder in enumerate(df_mean.loc[models_no_baseline].columns):
                    plt.scatter(np.arange(len(df_mean.loc[models_no_baseline].index))+0.1*i, df_mean.loc[models_no_baseline][grounder], label=grounder, alpha=0.5)
                    plt.errorbar(np.arange(len(df_mean.loc[models_no_baseline].index))+0.1*i, df_mean.loc[models_no_baseline][grounder], yerr=df_std.loc[models_no_baseline][grounder], fmt='o',capsize=5, alpha=0.5)
                if metric == step+'_task_mrr':
                    plt.axhline(y=df_mean.loc[baseline_model].mean(), color='black', linestyle='--', alpha=.7)  # Change color and linestyle as desired
                    plt.text(1.8, df_mean.loc[baseline_model].mean()-0.005, 'Baseline', color='black', fontsize=12, ha='center')
                    # print(df_mean.loc[baseline_model].values[0])
                plt.legend()
                plt.xticks(np.arange(len(df_mean.loc[models_no_baseline].index))+0.2, df_mean.loc[models_no_baseline].index.tolist(), rotation=0)
                plt.ylabel(metric_names[metric])
                plt.xlabel('Model')
                min = np.array([i for i in df_mean.loc[models].values.ravel() if i != np.nan])
                max = np.array([i for i in df_mean.loc[models].values.ravel() if i != np.nan])
                if min.min()<10:
                    print(min.min)
                    plt.ylim(min.min()-0.1,max.max()+0.13)
                plt.title(f'Grounders across models. Task: {task}, KGE: {KGE}, Set: {step}, Rule miner: {rule_miner}')
                plt.show()
                # SAVE THE FIGURE
                # if the directory does not exist, create it
                # plt.savefig(root_dir+'Grounders_across_models__'+'Task_'+task+'_Metric_'+metric+'_KGE_'+KGE+'_rule_'+rule_miner+'.png', dpi=300, bbox_inches='tight')
# Out:
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_supersmall  Rule miner:  None
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_supersmall  Rule miner:  amie
# Grounder     backward_1  backward_2  backward_3  domainbody   known
# Model_name
# cdcr             0.6605      0.6414      0.6283      0.6859  0.6663
# dcr              0.7105      0.6738      0.6776      0.6782  0.6650
# gsbr             0.6629      0.6664      0.6633      0.6638  0.6635
# no_reasoner      0.6622      0.6603      0.6603      0.6699  0.6637
# r2n              0.6695      0.6557      0.6502      0.6666  0.6651
# <built-in method min of numpy.ndarray object at 0x000001D12DB18F90>
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_supersmall  Rule miner:  ncrl
# Grounder     backward_1  backward_2  backward_3  domainbody   known
# Model_name
# cdcr             0.6684      0.6878      0.6943      0.6849  0.6635
# dcr              0.6644      0.6754      0.6793      0.6764  0.6635
# gsbr             0.6663      0.6630      0.6608      0.6631  0.6635
# no_reasoner      0.6622      0.6603      0.6603      0.6699  0.6637
# r2n              0.6687      0.6651      0.6695      0.6598  0.6653
# <built-in method min of numpy.ndarray object at 0x000001D12E9ED290>
# KGE:  complex  Metric:  test_task_mrr  Task:  kinship_family_small  Rule miner:  None
# Grounder     backward_1   known
# Model_name
# cdcr                NaN  0.5719
# dcr              0.6429  0.5691
# gsbr             0.6366  0.5693
# no_reasoner      0.5800  0.5800
# r2n              0.6843  0.5690
# KGE:  complex  Metric:  test_task_mrr  Task:  kinship_family_small  Rule miner:  amie
# Grounder     backward_1   known
# Model_name
# cdcr                NaN  0.5739
# dcr              0.7159  0.5756
# gsbr             0.7187  0.5761
# no_reasoner      0.5800  0.5797
# r2n              0.7760  0.5739
# KGE:  complex  Metric:  test_task_mrr  Task:  kinship_family_small  Rule miner:  ncrl
# Grounder     backward_1   known
# Model_name
# cdcr                NaN  0.5716
# dcr              0.5776  0.5690
# gsbr             0.5816  0.5690
# no_reasoner      0.5800  0.5800
# r2n              0.5784  0.5691
# KGE:  complex  Metric:  test_task_mrr  Task:  nations  Rule miner:  None
# Grounder     backward_1  backward_2   known
# Model_name
# cdcr             0.6066         NaN     NaN
# dcr              0.6043      0.6013  0.5994
# gsbr             0.6040      0.6019     NaN
# no_reasoner      0.6043         NaN     NaN
# r2n              0.6074      0.6073  0.6021
# KGE:  complex  Metric:  test_task_mrr  Task:  nations  Rule miner:  amie
# Grounder     backward_1  backward_2   known
# Model_name
# cdcr             0.6122         NaN     NaN
# dcr              0.6038      0.6017  0.6011
# gsbr             0.5970      0.6016     NaN
# no_reasoner      0.6043         NaN     NaN
# r2n              0.5945      0.6012  0.6003
# KGE:  complex  Metric:  test_task_mrr  Task:  nations  Rule miner:  ncrl
# Grounder     backward_1  backward_2   known
# Model_name
# cdcr             0.5978         NaN     NaN
# dcr              0.6077      0.6015  0.5994
# gsbr             0.6022      0.5997     NaN
# no_reasoner      0.6043         NaN     NaN
# r2n              0.6030      0.6037  0.6021
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s1  Rule miner:  None
# Grounder     backward_1  backward_2  backward_3  domainbody    full   known
# Model_name
# cdcr             0.7550      0.7855      0.7855      0.7661  0.7680  0.7481
# dcr              0.7615      0.7481      0.7481      0.7361  0.7557  0.7433
# gsbr             0.7595      0.7582      0.7582      0.7601  0.7747  0.7473
# no_reasoner      0.7414      0.7414      0.7414      0.7414  0.7414  0.7414
# r2n              0.7382      0.7511      0.7511      0.7105  0.7741  0.7640
# <built-in method min of numpy.ndarray object at 0x000001D12BFFF3F0>
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s1  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s1  Rule miner:  ncrl
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s2  Rule miner:  None
# Grounder     backward_1  backward_2  backward_3   known
# Model_name
# cdcr             0.7609      0.7393      0.7585  0.7383
# dcr              0.7735      0.7278      0.7384  0.7452
# gsbr             0.7526      0.7388      0.7412  0.7317
# no_reasoner      0.7256      0.7256      0.7256  0.7256
# r2n              0.7972      0.7511      0.7585  0.7813
# <built-in method min of numpy.ndarray object at 0x000001D12A6D4A50>
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s2  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s2  Rule miner:  ncrl
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s3  Rule miner:  None
# Grounder     backward_1  backward_2  backward_3   known
# Model_name
# cdcr             0.6120      0.6006      0.5948  0.5908
# dcr              0.6123      0.5945      0.6061  0.6092
# gsbr             0.6098      0.5896      0.6101  0.6094
# no_reasoner      0.6078      0.6078      0.6078  0.6078
# r2n              0.6120      0.6431      0.6229  0.6249
# <built-in method min of numpy.ndarray object at 0x000001D12A6E9650>
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s3  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s3  Rule miner:  ncrl

# %%
# # Now do the plot of the average over the models
# for task in tasks:
#     for metric in ['test_task_mrr']:
#         for KGE in KGEs:
#             for rule_miner in ['None', 'amie', 'ncrl']:
#                 print('KGE: ', KGE, ' Metric: ', metric, ' Task: ', task, ' Rule miner: ', rule_miner)
#                 if rule_miner not in dfs[task][KGE][metric].keys():
#                     continue
#                 df_mean = dfs_avg[task][KGE][metric][rule_miner]['mean']
#                 print(df_mean)
#                 df_std = dfs_avg[task][KGE][metric][rule_miner]['std']
#                 # Remove no reasoner and include a line where it is written baseline
#                 plt.figure(figsize=(10,5))
#                 plt.scatter(np.arange(len(df_mean.index)),df_mean.values.flatten(), alpha=0.5)
#                 plt.errorbar(np.arange(len(df_mean.index)),df_mean.values.flatten(), yerr=df_std.values.flatten(), fmt='o',capsize=5, alpha=0.5)
#                 if metric == step+'_task_mrr':
#                     baseline = dfs[task][KGE][metric][rule_miner]['mean'].loc[baseline_model].mean()
#                     plt.axhline(y=baseline, color='black', linestyle='--', alpha=.7)   
#                     plt.text(1.8, baseline-0.005, 'Baseline', color='black', fontsize=12, ha='center')
#                 # in the xlabel put the names of the grounders
#                 plt.xticks(np.arange(len(df_mean.index)), df_mean.index.tolist(), rotation=0)
#                 plt.ylabel(metric_names[metric])
#                 min = np.array([i for i in df_mean.values.flatten() if i != np.nan])
#                 max = np.array([i for i in df_mean.values.flatten() if i != np.nan])
#                 print(min.min() is np.nan)
#                 if min.min()<1:
#                     print(min.min)
#                     plt.ylim(min.min()-0.1,max.max()+0.1)
#                 plt.title(f'Grounders across models. Task: {task}, KGE: {KGE}, Set: {step}, Rule miner: {rule_miner}')
#                 plt.show()
#                 # SAVE THE FIGURE
#                 # if the directory does not exist, create it
#                 # plt.savefig(root_dir+'Grounders_across_models__'+'Task_'+task+'_Metric_'+metric+'_KGE_'+KGE+'_rule_'+rule_miner+'.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# # Grounders in x axis

# %%
rows = 'grounder'
cols = 'model_name'
# Table 1: rows:grounder, cols:Model, values: mrr
csv_dir = "C:\\Users\\rodri\\Downloads\\PhD\\Review_grounders\\keras_ns_grounders\\experiments\\countries\\hparamsearch\\results.csv"
# create the dict dfs with 4 levels of keys: task, KGE, metric, rule_miner
dfs = nested_dict(4, dict)
for task in tasks:
    for metric in metrics:
        for KGE in KGEs:
            for rule_miner in rule_miners:
                print('\nTask: ', task, 'KGE: ', KGE, ' Metric: ', metric,  ' Rule miner: ', rule_miner)
                # verify that the rule miner is within the values of Rule_Miner, else continue
                
                miners_available = df.loc[ (df['dataset_name'] == task) &(df['kge'] == KGE)]['rule_miner'].apply(lambda x: str(x)).unique()
                if (rule_miner not in miners_available):
                    print('Not available: rule_miner',rule_miner,'. Available: ',miners_available)
                    continue
                print('miners_available',miners_available)
                print('rule_miner',rule_miner)
                print('rul miner in miners_available',rule_miner in miners_available)
                # filter the df
                results = df.loc[ (df['dataset_name'] == task) &(df['kge'] == KGE) &(df['rule_miner'] == rule_miner) & df['grounder'].isin(grounders)].copy() #& (df['WeightLoss_Task'] == 0.5) & (df['Reasoner_depth'] == 1) & (df['EmbedSize'] == 100)].copy()
                # take only the columns grounder, model, test_task_mrr, test_concept_mrr
                results = results[[cols, rows, metric]]
                # Remove duplicates
                results = drop_duplicates_except_metric(results,cols,rows)
                # put the model_name as colums
                results = results.pivot(index=rows, columns=cols, values=metric)
                print('metric',metric)  
                if metric == 'test_task_mrr':
                    # in the column no_reasoner, put the values of the column test_concept_mrr
                    substitute = df.loc[(df['dataset_name'] == task) & (df['kge'] == KGE) &(df['rule_miner'] == rule_miner) & (df['model_name'] == baseline_model)][[cols,rows,baseline_metric]] #& (df['WeightLoss_Task'] == 0.5) & (df['Reasoner_depth'] == 1) & (df['EmbedSize'] == 100)][[cols,rows,baseline_metric]]
                    # drop the duplicates , based on all the colums except for 'test_task_mrr'
                    substitute = drop_duplicates_except_metric(substitute,cols,rows)
                    substitute = substitute.pivot(index=rows, columns=cols, values=baseline_metric)
                    # substitute the values in the table
                    if len(substitute) > 0:
                        results[baseline_model] = substitute[baseline_model] 
                    # print('\n\nresults',results)
                
                # obtain one df for the mean and one for the std
                results_mean, results_std = split_df(results)
                # append the results to dfs
                dfs[task][KGE][metric][rule_miner]['mean'] = results_mean
                dfs[task][KGE][metric][rule_miner]['std'] = results_std
                print('results_mean',results_mean)
                
                # with open(csv_dir, 'a') as f:
                #     f.write('\n Task : ,' + task + 'KGE : ,' + KGE + ', Metric: ,' + metric)
                #     f.write('\n ') 
                # results.to_csv(csv_dir, mode='a', header=True)  
print(task, KGE, metric, rule_miner)
results_mean
# Out:
# Task:  pharmkg_small KGE:  complex  Metric:  test_task_mrr  Rule miner:  No
# Not available: rule_miner No . Available:  []
#
# Task:  pharmkg_small KGE:  complex  Metric:  test_task_mrr  Rule miner:  amie
# Not available: rule_miner amie . Available:  []
#
# Task:  pharmkg_small_reason_2 KGE:  complex  Metric:  test_task_mrr  Rule miner:  No
# Not available: rule_miner No . Available:  []
#
# Task:  pharmkg_small_reason_2 KGE:  complex  Metric:  test_task_mrr  Rule miner:  amie
# Not available: rule_miner amie . Available:  []
#
# Task:  pharmkg_full KGE:  complex  Metric:  test_task_mrr  Rule miner:  No
# Not available: rule_miner No . Available:  []
#
# Task:  pharmkg_full KGE:  complex  Metric:  test_task_mrr  Rule miner:  amie
# Not available: rule_miner amie . Available:  []
#
# Task:  kinship_family KGE:  complex  Metric:  test_task_mrr  Rule miner:  No
# Not available: rule_miner No . Available:  []
#
# Task:  kinship_family KGE:  complex  Metric:  test_task_mrr  Rule miner:  amie
# Not available: rule_miner amie . Available:  []
#
# Task:  kinship_family_reason_2 KGE:  complex  Metric:  test_task_mrr  Rule miner:  No
# Not available: rule_miner No . Available:  []
#
# Task:  kinship_family_reason_2 KGE:  complex  Metric:  test_task_mrr  Rule miner:  amie
# Not available: rule_miner amie . Available:  []
#
# Task:  nations KGE:  complex  Metric:  test_task_mrr  Rule miner:  No
# Not available: rule_miner No . Available:  []
#
# Task:  nations KGE:  complex  Metric:  test_task_mrr  Rule miner:  amie
# Not available: rule_miner amie . Available:  []
#
# Task:  countries_s1 KGE:  complex  Metric:  test_task_mrr  Rule miner:  No
# miners_available ['No']
# rule_miner No
# rul miner in miners_available True
# n_rows_before 16 n_rows_after 15
# metric test_task_mrr
# n_rows_before 4 n_rows_after 3
# results_mean model_name    dcr  no_reasoner    r2n    rnm    sbr
# grounder
# backward_1  1.000        0.971  0.976  0.998  1.000
# backward_2  0.972        0.961  0.972  0.961  0.961
# backward_3  0.972        0.961  0.972  0.961  0.961
#
# Task:  countries_s1 KGE:  complex  Metric:  test_task_mrr  Rule miner:  amie
# Not available: rule_miner amie . Available:  ['No']
#
# Task:  countries_s2 KGE:  complex  Metric:  test_task_mrr  Rule miner:  No
# miners_available ['No']
# rule_miner No
# rul miner in miners_available True
# metric test_task_mrr
# results_mean model_name    dcr  no_reasoner    r2n    rnm    sbr
# grounder
# backward_1  0.944        0.936  0.948  0.945  0.944
# backward_2  0.949        0.936  0.922  0.936  0.936
# backward_3  0.949        0.936  0.922  0.936  0.936
#
# Task:  countries_s2 KGE:  complex  Metric:  test_task_mrr  Rule miner:  amie
# Not available: rule_miner amie . Available:  ['No']
#
# Task:  countries_s2_3rules KGE:  complex  Metric:  test_task_mrr  Rule miner:  No
# miners_available ['No']
# rule_miner No
# rul miner in miners_available True
# metric test_task_mrr
# results_mean model_name    dcr  no_reasoner    r2n    rnm    sbr
# grounder
# backward_1  0.996        0.936  0.946  0.992  0.994
# backward_2  0.933        0.936  0.941  0.947  0.947
# backward_3    NaN        0.936    NaN    NaN    NaN
#
# Task:  countries_s2_3rules KGE:  complex  Metric:  test_task_mrr  Rule miner:  amie
# Not available: rule_miner amie . Available:  ['No']
#
# Task:  countries_s3 KGE:  complex  Metric:  test_task_mrr  Rule miner:  No
# Not available: rule_miner No . Available:  []
#
# Task:  countries_s3 KGE:  complex  Metric:  test_task_mrr  Rule miner:  amie
# Not available: rule_miner amie . Available:  []
# countries_s3 complex test_task_mrr amie
# model_name    dcr  no_reasoner    r2n    rnm    sbr
# grounder
# backward_1  0.996        0.936  0.946  0.992  0.994
# backward_2  0.933        0.936  0.941  0.947  0.947
# backward_3    NaN        0.936    NaN    NaN    NaN

# %%
# select the times new roman font
plt.rcParams['font.family'] = 'Times New Roman'
root_dir = "C:\\Users\\rodri\\Downloads\\PhD\\Review_grounders\\keras_ns_grounders\\experiments\\countries\\hparamsearch\\figures\\"
for task in tasks:
    for metric in metrics:
        for KGE in KGEs:
            for rule_miner in rule_miners:
                print('KGE: ', KGE, ' Metric: ', metric, ' Task: ', task, ' Rule miner: ', rule_miner)
                if rule_miner not in dfs[task][KGE][metric].keys():
                    continue
                df_mean = dfs[task][KGE][metric][rule_miner]['mean'][models_no_baseline]
                df_std = dfs[task][KGE][metric][rule_miner]['std'][models_no_baseline]
                df_mean_baseline = dfs[task][KGE][metric][rule_miner]['mean'][baseline_model].mean()
                # df_std_baseline = dfs[task][KGE][metric][rule_miner]['std'][baseline_model]
                # Remove no reasoner and include a line where it is written baseline
                plt.figure(figsize=(10,5))
                for i,model in enumerate(df_mean.columns):
                    print(model)
                    try:
                        plt.scatter(np.arange(len(df_mean.index))+0.1*i, df_mean[model], label=models_name[model], alpha=.8,linewidth=5) 
                        plt.errorbar(np.arange(len(df_mean.index))+0.1*i, df_mean[model], yerr=df_std[model], fmt='o',capsize=5, alpha=.7,linewidth=2)
                    except:
                        continue
                plt.legend()
                labels = [ground_name[i] for i in df_mean.index]
                plt.xticks(np.arange(len(df_mean.index))+0.2, labels, rotation=0, fontsize=18)
                plt.ylabel(metric_names[metric]+' on '+step+' set', fontsize=18)
                plt.xlabel('Grounder', fontsize=18)
                min = np.array([i for i in df_mean.values.ravel() if not np.isnan(i)])  
                max = np.array([i for i in df_mean.values.ravel() if not np.isnan(i)]) 
                print('Best result: ',max.max(), 'Baseline: ', np.round(df_mean_baseline,3))
                if min.min()<1: #max.max()<=.9:
                    plt.ylim(min.min()-0.1,max.max()+0.1)
                # elif max.max()>=.9:
                #     plt.ylim(min.min()-0.1,1.01)
                if metric == step+'_task_mrr':
                    plt.axhline(y=df_mean_baseline, color='black', linestyle='--', alpha=.7)  # Change color and linestyle as desired
                    plt.text(1.8, df_mean_baseline-0.009, 'Baseline', color='black', fontsize=15, ha='right',clip_on=True)
                    plt.text(0.05, 0.05, 'Best result: '+str(np.round(max.max(),3))+'       Baseline, KGE Complex: '+str(np.round(df_mean_baseline,3)), transform=plt.gca().transAxes,
                            fontsize=15, verticalalignment='bottom', horizontalalignment='left')
                plt.title(f'Results for the dataset {dataset_names[task]}', fontsize=18)
                # plt.title(f'Dataset: {dataset_names[task]}, KGE: {KGE}, Set: {step}, Rule miner: {rule_miner}')
                plt.show()
                # SAVE THE FIGURE
                # if the directory does not exist, create it
                # os.makedirs(root_dir) if not os.path.exists(root_dir) else None
                # plt.savefig(root_dir+'Grounders_across_models__'+'Task_'+task+'_Metric_'+metric+'_KGE_'+KGE+'_rule_'+rule_miner+'.png', dpi=300, bbox_inches='tight')
# Out:
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_small  Rule miner:  No
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_small  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_small_reason_2  Rule miner:  No
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_small_reason_2  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_full  Rule miner:  No
# KGE:  complex  Metric:  test_task_mrr  Task:  pharmkg_full  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  kinship_family  Rule miner:  No
# KGE:  complex  Metric:  test_task_mrr  Task:  kinship_family  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  kinship_family_reason_2  Rule miner:  No
# KGE:  complex  Metric:  test_task_mrr  Task:  kinship_family_reason_2  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  nations  Rule miner:  No
# KGE:  complex  Metric:  test_task_mrr  Task:  nations  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s1  Rule miner:  No
# sbr
# rnm
# dcr
# r2n
# Best result:  1.0 Baseline:  0.964
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s1  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s2  Rule miner:  No
# sbr
# rnm
# dcr
# r2n
# Best result:  0.949 Baseline:  0.936
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s2  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s2_3rules  Rule miner:  No
# sbr
# rnm
# dcr
# r2n
# Best result:  0.996 Baseline:  0.936
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s2_3rules  Rule miner:  amie
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s3  Rule miner:  No
# KGE:  complex  Metric:  test_task_mrr  Task:  countries_s3  Rule miner:  amie

# %%
# # for every df of dfs, create a new df with the average over the models
# dfs_avg = nested_dict(4, dict)
# for task in tasks:
#     for metric in metrics:
#         for KGE in KGEs:
#             for rule_miner in rule_miners:
#                 for types in ['mean', 'std']:
#                     # print(types, 'KGE: ', KGE, ' Metric: ', metric, ' Task: ', task, ' Rule miner: ', rule_miner)
#                     if rule_miner not in dfs[task][KGE][metric].keys():
#                         continue
#                     dfi = dfs[task][KGE][metric][rule_miner][types].copy()
#                     # select from dfi the models that are in models_no_baseline
#                     dfi = dfi[models_no_baseline]
#                     dfi = dfi.mean(axis=0)
#                     dfi = pd.DataFrame(dfi)
#                     # set the name of the column as the metric
#                     dfi.columns = [metric]
#                     dfs_avg[task][KGE][metric][rule_miner][types] = dfi
#                     # print(dfi)
# dfi

# %% [markdown]
# - amie vs ncrl: amie is better
# - models: no difference between models
# - improvement over baseline: all datasets (kinship family, pharmkg, countries) excep nations
#     - in the rules generated, the grounder performance depends on the rules generator?
#     - models: no best model
#     - grounders: no best grounder overall, then go for back1 because of computing time. Do plot with axis inverted
